# %% [markdown]
# # DataNeeded

# %% [markdown]
# ## 1 預處理

# %%
import pandas as pd
import json
import os
import re

# %%
# 讀取數據文件
Adata = pd.read_csv("[2] 2019320fin.csv", encoding="utf-8-sig")

Adata.head()
# Out:
#        id city         ctripName         lon        lat  value  stars  price  \
# 0  345025   北京       北京中奥马哥孛罗大酒店  116.408622  40.005020    4.8      5    926
# 1  345029   北京          北京西单美爵酒店  116.374998  39.903426    4.5      4    788
# 2  346488   北京          北京北方佳苑饭店  116.412954  39.910324    4.3      4    528
# 3  347308   北京        北京王府井希尔顿酒店  116.413340  39.914840    4.6      0   1321
# 4  347310   北京  北京长城饭店(原喜来登长城饭店)  116.463587  39.944516    4.4      5    758
#
#    isquality  strategymedal  ...    差评  有图片    商务出差   朋友出游   情侣出游    家庭亲子  \
# 0          1              0  ...   192  217  3512.0  345.0  229.0   509.0
# 1          0              0  ...   174  275  2405.0  262.0  303.0  1068.0
# 2          1              0  ...   304  203  1746.0  302.0  222.0  1050.0
# 3          0              0  ...   157  458  1536.0  403.0  381.0  1578.0
# 4          1              0  ...   605  404  4893.0  459.0  352.0   548.0
#
#     独自出行   代人预订     其他  房型类数
# 0  332.0  212.0  309.0   6.0
# 1  169.0  136.0  244.0  14.0
# 2  203.0  161.0  416.0  10.0
# 3  216.0   98.0  239.0  15.0
# 4  353.0  269.0  369.0  15.0
#
# [5 rows x 68 columns]

# %% [markdown]
# | column   name  | describe                                 | \|   | column name        | describe                                           |
# | -------------- | ---------------------------------------- | ---- | ------------------ | -------------------------------------------------- |
# | id             | 酒店編号(base ctrip)                     | \|   | input_QunarName    | 輸入搜索的酒店名                                   |
# | city           | 所在熱門城市                             | \|   | get_qunarName      | 在Qunar平臺檢索後的酒店名                          |
# | ctripArea      | 酒店所在區域(ctrip)                      | \|   | qunarValue         | 酒店評分(Qunar)                                    |
# | ctripName      | 酒店名稱(ctrip)                          | \|   | qunarCommentsCount | 酒店評論數(Qunar)                                  |
# | value          | 酒店總評分(ctrip)                        | \|   | qunarURL           | 酒店網址(Qunar)                                    |
# | stars          | 國家評定等級(ctrip)                      | \|   | fliggy_inputName   | 輸入搜索的酒店名                                   |
# | price          | 酒店價格(ctrip 2018-11-24)               | \|   | fliggyName         | 在Fliggy平臺檢索後的酒店名                         |
# | isquality      | 是否品質保證(ctrip)                      | \|   | diffValue          | fliggy_inputName &   fliggy_inputName 的文本值差異 |
# | strategymedal  | 是否特牌(ctrip)                          | \|   | isTrust            | 是否信用入住(fliggy)                               |
# | goldmedal      | 是否金牌(ctrip)                          | \|   | fliggyPrice        | 酒店價格(fliggy)                                   |
# | silvermedal    | 是否銀牌(ctrip)                          | \|   | fliggyValue        | 酒店評分(fliggy)                                   |
# | diamondRank    | 攜程評定鑽石等級(ctrip)                  | \|   | fliggyvolume       | 酒店評論數量(fliggy)                               |
# | judgementscore | 用戶推薦入住百分比(ctrip 2018-11-24)     | \|   | fliggyURL          | 網址(fliggy)                                       |
# | commentscount  | 酒店評論數(ctrip 2018-11-24)             | \|   |                    |                                                    |
# | labelscount    | 區域或酒店類型標籤數量(ctrip 2018-11-24) | \|   |                    |                                                    |
# | strlabels      | 區域或酒店類型標籤內容(ctrip 2018-11-24) | \|   |                    |                                                    |
# | servicescount  | 酒店服務項目數量(ctrip)                  | \|   |                    |                                                    |
# | strservices    | 酒店服務項目內容                         | \|   |                    |                                                    |
# | ctripURL       | 酒店網址(ctrip)                          | \|   |                    |                                                    |

# %% [markdown]
# ---

# %% [markdown]
# ## mathcing 2
#
# Exact Match X1 城市、X4星级，然后找价格在实验组价格的上下10%区间里的所有酒店，计算他们Diff_Rating=CtripRating-QunarRating, 然后选择Diff_Rating为中位数的哪一家作为match的对照组。

# %% [markdown]
# <font color="blue">- 攜程選優酒店 Lf ( 初步定義: 持 strategymedal的酒店)</font>

# %%
# 特徵選擇
selFeature = [
    "id",
    "city",
    "ctripName",
    "stars",
    "strategymedal",
    "goldmedal",
    "silvermedal",
    "price",
    "value",
    "qunarValue",
]

# %%
# 獲取優選酒店
# Lf = Adata[Adata.strategymedal == 1]
# 重新定义 優選酒店
Lf = Adata[(Adata.strategymedal + Adata.goldmedal + Adata.silvermedal) != 0]
# 优选酒店数量
rre = Lf.strategymedal.shape[0]
Lf = Lf[selFeature]
Lf.sort_values("id", inplace=True)
Lf["diffValue"]=Lf.value-Lf.qunarValue
Lf.reset_index(inplace=True, drop=True)
print(Lf.shape)
Lf.head(3)
# Out:
# (2972, 11)
#        id city    ctripName  stars  strategymedal  goldmedal  silvermedal  \
# 0  344928   三亚  三亚亚龙湾万豪度假酒店      5              0          1            0
# 1  345001   上海       上海日航饭店      5              0          0            1
# 2  345008   广州   广州方圆奥克伍德豪景      0              0          1            0
#
#    price  value  qunarValue  diffValue
# 0    951    4.6         4.6        0.0
# 1    970    4.4         4.3        0.1
# 2   1040    4.5         4.6       -0.1

# %% [markdown]
# - <font color="blue"> 攜程非選優酒店 Rf

# %%
Rf = Adata[(Adata.strategymedal + Adata.goldmedal + Adata.silvermedal) == 0]
Rf = Rf[selFeature]
Rf.sort_values("id", inplace=True)
Rf["diffValue"]=Rf.value-Rf.qunarValue
Rf.reset_index(inplace=True, drop=True)
print(Rf.shape)
Rf.head()
# Out:
# (12915, 11)
#        id city            ctripName  stars  strategymedal  goldmedal  \
# 0  141587   深圳          深雅酒店(深圳时尚店)      0              0          0
# 1  344612   南京  南京卡特快捷宾馆(原摩卡庄园快捷酒店)      0              0          0
# 2  344853   广州            广州富力君悦大酒店      5              0          0
# 3  344857   广州               广州花园酒店      5              0          0
# 4  344881   广州              广州中国大酒店      5              0          0
#
#    silvermedal  price  value  qunarValue  diffValue
# 0            0    121    2.9         3.0       -0.1
# 1            0    158    3.0         3.4       -0.4
# 2            0   1269    4.6         4.5        0.1
# 3            0   1166    4.6         4.6        0.0
# 4            0    902    4.5         4.5        0.0

# %% [markdown]
# - <font color="blue">數據文件輸出

# %%
Lf.to_csv(r"H1\H1 Lf Ctrip and Qunar.csv",encoding="utf-8-sig")
Rf.to_csv(r"H1\H1 Rf Ctrip and Qunar.csv",encoding="utf-8-sig")

# %% [markdown]
# - match

# %%
#from math import radians, cos, sin, asin, sqrt
import pandas as pd
import json
import os
import re
import numpy as np


Lf = pd.read_csv(r"H1\H1 Lf Ctrip and Qunar.csv", encoding="utf-8-sig")
RRf = pd.read_csv(r"H1\H1 Rf Ctrip and Qunar.csv", encoding="utf-8-sig")


# ----------------------------------------------------hard match
num = 0
resultS = []
resultD = []
k = 1
for _ in Lf.id:
    Rf = RRf.copy()
    # match 所在城市
    Rf = Rf[Rf.city == Lf.loc[num].city]
    # match 酒店星级
    Rf = Rf[Rf.stars == Lf.loc[num].stars]
    t = Lf.loc[num].price

    # 价格差
    Rf = Rf[(abs(Rf.price-t))/t <= 0.1]
    if Rf.shape[0] == 0:
        num += 1
        continue
    # 将配对到的数量存起来
    resultS.append(Rf.shape[0])
    # 携程与去哪的评分差值排序
    Rf.sort_values(["diffValue"],inplace=True)
    
    ind=Rf["diffValue"].shape[0]//2
    # 取出中位数
    Rf=Rf.iloc[ind:ind+1]

#     Rf["matching to id"] = Lf.loc[num].id
#     Rf["matching to name"] = Lf.loc[num].ctripName
#     print(Rf.id.tolist()[0])
    t = {
        "matchingNum": [k, k],
        "matchingLabel": [1, 0],
        "id": [Lf.loc[num].id, Rf.id.tolist()[0]],
        "city": [Lf.loc[num].city, Rf.city.tolist()[0]],
        "hotelname": [Lf.loc[num].ctripName, Rf.ctripName.tolist()[0]],
        "stars": [Lf.loc[num].stars, Rf.stars.tolist()[0]],
        "hotelprice": [Lf.loc[num].price, Rf.price.tolist()[0]],
        "diffValue":[Lf["diffValue"].tolist()[0],Rf["diffValue"].tolist()[0]],
        "ValueMedian": ["", ind]
    }

    num += 1
    k += 1
    resultD.append(pd.DataFrame(t))


resultD[0]
# Out:
#    matchingNum  matchingLabel      id city      hotelname  stars  hotelprice  \
# 0            1              1  345001   上海         上海日航饭店      5         970
# 1            1              0  374924   上海  上海新发展亚太JW万豪酒店      5         958
#
#    diffValue ValueMedian
# 0        0.0
# 1        0.1           5

# %%
t1=resultS.count(0)
t2=len(resultS)
t3=max(resultS)
str1=f"匹配失败数量:{t2-t1},匹配失败数量:{t1},匹配最多数量:{t3}"

# print(str1,"\n",resultS)

# %%
# 將所有匹配到的酒店合併成一個DF 對象
fa = pd.concat(resultD, axis=0, sort=False)
fa=fa.reset_index(drop="index")
sete=[]
for i in range(fa.shape[0]):
    D=Adata[Adata.id==fa.iloc[i].id]
    sete.append(D)

# %%
fa.columns.tolist()
# Out:
# ['matchingNum',
#  'matchingLabel',
#  'id',
#  'city',
#  'hotelname',
#  'stars',
#  'hotelprice',
#  'diffValue',
#  'ValueMedian']

# %%
matchinset=pd.concat(sete,axis=0)
matchinset.reset_index(drop="index",inplace=True)

# %%
outfile=pd.concat([matchinset,fa[["matchingNum","matchingLabel","diffValue","ValueMedian"]]],axis=1)

# %%
outfile.to_csv("[3] matchHotel.csv",encoding="utf-8-sig")

# %%
filename="[3] matchHotel"

# %% [markdown]
# ## 输出match 酒店

# %%
def tocsv2(filename):
    tager=pd.read_csv(f"{filename}.csv",encoding="utf-8-sig")

    x=tager.iloc[0::2,1:]
    x.reset_index(drop="index",inplace=True)

    y=tager.iloc[1::2,1:]
    y.columns=[(i+"_matched Result") for i in y.columns]
    y.reset_index(drop="index",inplace=True)

    z=pd.concat([x,y],axis=1)
    z.to_csv(f"{filename}_.csv",encoding="utf-8-sig")
    
tocsv2("[3] matchHotel")

# %% [markdown]
# ---

# %% [markdown]
# ## **在此 补充包含配对酒店的评论数据表文件夹 rating后,再进行下一步的操作

# %%
import os
filecsv = pd.read_csv("[3] matchHotel.csv", encoding="utf-8-sig")

def getDF(id):
    filename = f"{str(id)}.csv"
    with open("rating\\"+filename, "r", encoding="utf-8-sig") as f:
        ret = ""
        for i in range(200):
            ret += (f.readline())
        try:
            a = ret.split("commentAccount")
            if len(a) > 1:
                with open("rating2\\"+filename, "w", encoding="utf-8-sig") as fw:
                    fw.write("commentAccount" + a[1])
                return 0
            else:
                return id
        except:
            print(filename)


yy = list(set(filecsv.id.tolist()))
# print(len(yy))
re=[]
for i in yy:
    a=getDF(i)
    if a!=0:
        re.append(a)

# %% [markdown]
# ## 处理并输出统计前100条评论标准差的数据

# %%
filecsv = pd.read_csv("[3] matchHotel.csv", encoding="utf-8-sig")
listname=["id","city","ctripName","matchingNum","matchingLabel","diffValue","ValueMedian","value","stars","price"]
filecsv=filecsv[listname]
STD = []

# 将评论中前100条数据取出
for i in filecsv.id:
    try:
        t = pd.read_csv(f"{os.getcwd()}\\rating2\\{i}.csv",
                        encoding="utf-8-sig")
        STD.append(t.indiRating[:100].std())
        
    except:
        STD.append("NaN")
        
# 插入新的数据 STD 标准差

# %%
filecsv.insert(8,column="STD",value=STD)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-fc47dd3877cd> in <module>()
# ----> 1 filecsv.insert(8,column="STD",value=STD)
#       2 filecsv
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3217         value = self._sanitize_column(column, value, broadcast=False)
#    3218         self._data.insert(loc, column, value,
# -> 3219                           allow_duplicates=allow_duplicates)
#    3220
#    3221     def assign(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# -> 4338             raise ValueError('cannot insert {}, already exists'.format(item))
#    4339
#    4340         if not isinstance(loc, int):
#
# ValueError: cannot insert STD, already exists

# %% [markdown]
# - 输出数据

# %%
filecsv
# Out:
#             id city              ctripName  matchingNum  matchingLabel  \
# 0       345001   上海                 上海日航饭店            1              1
# 1       374924   上海          上海新发展亚太JW万豪酒店            1              0
# 2       345008   广州             广州方圆奥克伍德豪景            2              1
# 3       456162   广州              广州雅诗阁服务公寓            2              0
# 4       345012   广州          桔子水晶酒店(广州淘金店)            3              1
# 5       512410   广州               广州船舶太古酒店            3              0
# 6       345025   北京            北京中奥马哥孛罗大酒店            4              1
# 7       374795   北京               北京伯豪瑞廷酒店            4              0
# 8       345029   北京               北京西单美爵酒店            5              1
# 9       638075   北京                北京金码大酒店            5              0
# 10      345046   上海             上海富豪环球东亚酒店            6              1
# 11      346309   上海                 上海锦江饭店            6              0
# 12      345050   上海   上海静安禧睿酒店(原禧睿酒店南京西路店)            7              1
# 13     1058440   上海         维也纳酒店(上海宝山吴淞店)            7              0
# 14      345052   上海               上海美丽园大酒店            8              1
# 15      427046   上海              上海齐鲁万怡大酒店            8              0
# 16      345065   三亚               三亚万丽度假酒店            9              1
# 17      429907   三亚            三亚明申高尔夫度假酒店            9              0
# 18      345067   三亚           三亚海棠湾喜来登度假酒店           10              1
# 19      346673   三亚        三亚半山半岛度假酒店(全套房)           10              0
# 20      345069   三亚       三亚海棠湾万达希尔顿逸林度假酒店           11              1
# 21      346673   三亚        三亚半山半岛度假酒店(全套房)           11              0
# 22      345078   三亚           三亚亚龙湾美高梅度假酒店           12              1
# 23      429615   三亚   三亚亚龙湾君澜度假酒店(原假日度假酒店)           12              0
# 14          0.0          NaN    4.5  0.878369      4    735
# 15          0.1          1.0    4.6  0.629365      4    725
# 16          0.0          NaN    4.7  0.487504      0    538
# 17          0.2          3.0    4.6  0.772389      0    549
# 18          0.0          NaN    4.6  0.793605      0    672
# 19          0.0          2.0    4.6  0.980148      0    723
# 20          0.0          NaN    4.5   1.07491      0    760
# 21          0.0          1.0    4.6  0.980148      0    723
# 22          0.0          NaN    4.7  0.327763      0   1249
# 23          0.1          1.0    4.6  0.629423      0   1167
# 24          0.0          NaN    4.7  0.667614      0   1250
# 25          0.1          1.0    4.6  0.629423      0   1167
# 26          0.0          NaN    4.6  0.717259      0    317
# 27          0.0          9.0    4.6  0.688886      0    341
# 28          0.0          NaN    4.5   1.14648      0    360
# 29          0.0          5.0    4.6  0.688886      0    341
# ...         ...          ...    ...       ...    ...    ...
# 5764        0.0          NaN    4.5  0.914716      0    290
# 5765        0.0         91.0    4.4  0.946443      0    261
# 5766        0.0          NaN    4.7  0.546962      0    599
# 5767        0.0         15.0    4.4   1.07378      0    572
# 5768        0.0          NaN    4.9   0.24151      0     17
# 5769        0.3          2.0    4.7  0.518256      0     18
# 5770        0.0          NaN    4.4   0.75053      0     45
# 5771        0.4          4.0    4.9  0.399313      0     45
# 5772        0.0          NaN    4.9  0.278532      0    710
# 5773        0.1          4.0    4.4  0.884485      0    645
# 5774        0.0          NaN    4.8  0.601107      0     74
# 5775        0.1         16.0    4.0    1.1809      0     71
# 5776        0.0          NaN    4.8  0.507092      0    195
# 5777        0.0        111.0    4.4   0.91548      0    177
# 5778        0.0          NaN    4.3   1.17447      0    370
# 5779        0.0         52.0    4.5  0.883493      0    404
# 5780        0.0          NaN    4.8  0.421762      0    117
# 5781        0.0         77.0    4.1  0.981701      0    118
# 5782        0.0          NaN    4.8  0.858481      0    116
# 5783        0.0         71.0    3.4   1.23741      0    113
# 5784        0.0          NaN    4.9  0.457127      0     36
# 5785        0.0          6.0    4.6   1.01926      0     35
# 5786        0.0          NaN    4.9   0.70066      0   2680
# 5787       -0.1          0.0    4.8  0.928775      0   2696
# 5788        0.0          NaN    4.9      0.02      0    278
# 5789        0.0         50.0    4.8  0.580193      0    291
# 5790        0.0          NaN    4.9   0.40639      0    313
# 5791        0.1         87.0    4.3  0.878704      0    294
# 5792        0.0          NaN    4.9  0.423476      0    115
# 5793        0.0         66.0    4.9  0.646932      0    121
#
# [5794 rows x 11 columns]

# %%
filecsv.to_csv("[4] H1 matching with STD.csv",encoding="utf-8-sig")

# %%
def tocsv2(filename):
    tager=pd.read_csv(f"{filename}.csv",encoding="utf-8-sig")

    x=tager.iloc[0::2,1:]
    x.reset_index(drop="index",inplace=True)

    y=tager.iloc[1::2,1:]
    y.columns=[(i+"_matched Result") for i in y.columns]
    y.reset_index(drop="index",inplace=True)

    z=pd.concat([x,y],axis=1)
    z.to_csv(f"{filename}_.csv",encoding="utf-8-sig")
    
tocsv2("[4] H1 matching with STD")

# %% [markdown]
# ## 输出包含所有评论的数据

# %%
SerTD = []
H1data = pd.read_csv("[4] H1 matching with STD.csv", encoding="utf-8-sig")
# 去除无效数据
H1data=H1data.iloc[:,2:]
H1data.head()
listname=["id","city","ctripName","matchingNum","matchingLabel","diffValue","ValueMedian","value","stars","price","STD"]
H1data=H1data[listname]
H1data
# Out:
#             id city              ctripName  matchingNum  matchingLabel  \
# 0       345001   上海                 上海日航饭店            1              1
# 1       374924   上海          上海新发展亚太JW万豪酒店            1              0
# 2       345008   广州             广州方圆奥克伍德豪景            2              1
# 3       456162   广州              广州雅诗阁服务公寓            2              0
# 4       345012   广州          桔子水晶酒店(广州淘金店)            3              1
# 5       512410   广州               广州船舶太古酒店            3              0
# 6       345025   北京            北京中奥马哥孛罗大酒店            4              1
# 7       374795   北京               北京伯豪瑞廷酒店            4              0
# 8       345029   北京               北京西单美爵酒店            5              1
# 9       638075   北京                北京金码大酒店            5              0
# 10      345046   上海             上海富豪环球东亚酒店            6              1
# 11      346309   上海                 上海锦江饭店            6              0
# 12      345050   上海   上海静安禧睿酒店(原禧睿酒店南京西路店)            7              1
# 13     1058440   上海         维也纳酒店(上海宝山吴淞店)            7              0
# 14      345052   上海               上海美丽园大酒店            8              1
# 15      427046   上海              上海齐鲁万怡大酒店            8              0
# 16      345065   三亚               三亚万丽度假酒店            9              1
# 17      429907   三亚            三亚明申高尔夫度假酒店            9              0
# 18      345067   三亚           三亚海棠湾喜来登度假酒店           10              1
# 19      346673   三亚        三亚半山半岛度假酒店(全套房)           10              0
# 20      345069   三亚       三亚海棠湾万达希尔顿逸林度假酒店           11              1
# 21      346673   三亚        三亚半山半岛度假酒店(全套房)           11              0
# 22      345078   三亚           三亚亚龙湾美高梅度假酒店           12              1
# 23      429615   三亚   三亚亚龙湾君澜度假酒店(原假日度假酒店)           12              0
# 24      345082   三亚               三亚文华东方酒店           13              1
# 25      429615   三亚   三亚亚龙湾君澜度假酒店(原假日度假酒店)           13              0
# 26      345084   三亚            三亚锦江宝宏大酒店主楼           14              1
# 27     9216515   三亚              三亚安吉拉假日酒店           14              0
# 28      345088   三亚             三亚天泽海韵度假酒店           15              1
# 29     9216515   三亚              三亚安吉拉假日酒店           15              0
# ...        ...  ...                    ...          ...            ...
# 5764  23239463   上海                 上海慕弈酒店         2883              1
# 5765    428286   上海  如家快捷酒店(上海大宁国际广中路马戏城店)         2883              0
# 5766  23406093   广州    长隆香江酒店(广州长隆野生动物世界店)         2884              1
# 5767    397466   广州            广州嘉鸿华美达广场酒店         2884              0
# 5768  23565136   成都           成都loft国际青年旅舍         2885              1
# 5769   6480230   成都                 成都城市驿站         2885              0
# 5770  23572246   青岛           红璞公寓(青岛闽江路店)         2886              1
# 5771   5374771   青岛             青岛市新起点商务旅馆         2886              0
# 5772  23623292   厦门            厦门三个厦大人与初民宿         2887              1
# 5773    426864   厦门            厦门鼓浪屿海上花园酒店         2887              0
# 5774  23649943   上海    朋派青年艺术酒店(上海火车站北广场店)         2888              1
# 5775   5248536   上海    上海易佰连锁酒店国家会展中心曹安公路店         2888              0
# 5776  23801920   成都             成都埃德蒙顿服务公寓         2889              1
# 5777   8655641   成都             七舍酒店(欢乐谷店)         2889              0
# 5778  23885449   深圳                 深圳怡馨酒店         2890              1
# 5779   6534635   深圳           深圳耶姆酒店公寓来福士店         2890              0
# 5780  23944424   广州               广州丽凯酒店公寓         2891              1
# 5778        0.0          NaN    4.3      0    370  1.174474
# 5779        0.0         52.0    4.5      0    404  0.883493
# 5780        0.0          NaN    4.8      0    117  0.421762
# 5781        0.0         77.0    4.1      0    118  0.981701
# 5782        0.0          NaN    4.8      0    116  0.858481
# 5783        0.0         71.0    3.4      0    113  1.237414
# 5784        0.0          NaN    4.9      0     36  0.457127
# 5785        0.0          6.0    4.6      0     35  1.019263
# 5786        0.0          NaN    4.9      0   2680  0.700660
# 5787       -0.1          0.0    4.8      0   2696  0.928775
# 5788        0.0          NaN    4.9      0    278  0.020000
# 5789        0.0         50.0    4.8      0    291  0.580193
# 5790        0.0          NaN    4.9      0    313  0.406390
# 5791        0.1         87.0    4.3      0    294  0.878704
# 5792        0.0          NaN    4.9      0    115  0.423476
# 5793        0.0         66.0    4.9      0    121  0.646932
#
# [5794 rows x 11 columns]

# %%
g1=H1data.id.tolist()
for i in range(len(g1)):
    try:
        t = pd.read_csv(f"{os.getcwd()}\\rating2\\{g1[i]}.csv", encoding="utf-8-sig")
    except:
        a = [H1data.iloc[i:i+1, :]]
        dfe = pd.concat(a, axis=0)
        dfe.insert(5, column="用户评分", value=["NaN"])
        dfe.insert(5, column="用户序号", value=["NaN"])
        SerTD.append(dfe)


    a = [H1data.iloc[i:i+1, :] for _ in range(t.indiRating[:100].shape[0])]
    dfe = pd.concat(a, axis=0)

    dfe.insert(5, column="用户评分", value=(t.indiRating[:100]).tolist())
    dfe.insert(5, column="用户序号", value=[j+1 for j in range(t.indiRating[:100].shape[0])])
    if i%500==0:
        print(i)
    SerTD.append(dfe)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500

# %%
dfe=pd.concat(SerTD,axis=0)
dfe.reset_index(drop="index",inplace=True)
dfe.head()
# Out:
#        id city ctripName  matchingNum  matchingLabel 用户序号 用户评分  diffValue  \
# 0  345001   上海    上海日航饭店            1              1    1  4.5        0.0
# 1  345001   上海    上海日航饭店            1              1    2  4.3        0.0
# 2  345001   上海    上海日航饭店            1              1    3    3        0.0
# 3  345001   上海    上海日航饭店            1              1    4    5        0.0
# 4  345001   上海    上海日航饭店            1              1    5  3.8        0.0
#
#    ValueMedian  value  stars  price       STD
# 0          NaN    4.4      5    970  1.169691
# 1          NaN    4.4      5    970  1.169691
# 2          NaN    4.4      5    970  1.169691
# 3          NaN    4.4      5    970  1.169691
# 4          NaN    4.4      5    970  1.169691

# %% [markdown]
# - 从上往下阅读

# %%
dfe.to_csv("[4] H1 matching with allrating.csv",encoding="utf-8-sig")

# %% [markdown]
# - 左右两边阅读

# %%
ret=[]
for i in range(1,int(dfe.matchingNum.max())+1):
    t = dfe[dfe.matchingNum == i]
    T = t[t.ctripName == t.iloc[1].ctripName]
    T.reset_index(drop="index", inplace=True)
    TT = t[t.ctripName != t.iloc[1].ctripName]
    TT.columns=[(str(i)+"RM") for i in TT.columns.tolist()]
    TT.reset_index(drop="index", inplace=True)
    temp=pd.concat([T, TT], axis=1)
    ret.append(temp)

# %%
matchingwithallrating=pd.concat(ret,sort=False, axis=0)
matchingwithallrating.reset_index(drop="index", inplace=True)

# %%
matchingwithallrating.to_csv("[4] H1 matching with allrating_marge.csv",encoding="utf-8-sig")

# %% [markdown]
# ---
